# %% [markdown]
# <a href="https://colab.research.google.com/github/amanmohd63/IntershipProject/blob/main/InternshipProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

data = pd.read_csv("/content/Different_stores_data.csv")

data["total_amount"] = data["quantity"] * data["selling_price_per_unit"]

customer_data = data.groupby("customer_id").agg({
    "total_amount":"sum",
    "quantity":"sum",
    "age":"first"
})
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = scaler.fit_transform(customer_data)

kmeans = KMeans(n_clusters=4, random_state=42)

labels = kmeans.fit_predict(x)

customer_data["cluster"] = labels

plt.scatter(
    customer_data["total_amount"],
    customer_data["quantity"],
    c=labels,
    cmap="rainbow"
)

plt.xlabel("Total Amount Spent")
plt.ylabel("Total Quantity Purchased")
plt.title("Customer Segmentation using K-Means")
plt.show()

print(customer_data.groupby("cluster").mean())
# Out:
#          total_amount   quantity        age
# cluster
# 0        22000.641832  25.953401  31.604631
# 1         8270.989542  13.835078  31.805941
# 2        12510.326247  17.999374  57.831350
# 3        38260.742041  32.570978  49.602524

# %%
# !git clone https://github.com/amanmohd63/IntershipProject.git
# Out:
# Cloning into 'IntershipProject'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 1.71 MiB | 5.79 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd IntershipProject
# !ls
# Out:
# /content/IntershipProject
#  Different_stores_data.csv  'sample data.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/amanmohd63/IntershipProject.git
# Out:
# /content/drive/MyDrive
# fatal: destination path 'IntershipProject' already exists and is not an empty directory.

# %%
# %cd /content/IntershipProject
# Out:
# [Errno 2] No such file or directory: '/content/IntershipProject'
# /content/drive/MyDrive

# %%
# !git clone https://github.com/amanmohd63/IntershipProject
# Out:
# Cloning into 'IntershipProject'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 16 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 1.71 MiB | 11.86 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
cd IntershipProject
# Out:
# /content/IntershipProject

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .git/amanmohd63/IntershipProject
# Out:
# fatal: pathspec '.git/amanmohd63/IntershipProject' did not match any files
